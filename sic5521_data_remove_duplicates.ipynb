# %%
import pandas as pd
from google.colab import sheets

file_path = '/content/drive/MyDrive/sic5521_ready_to_viz.csv'
sic5521_ready_to_viz = pd.read_csv(file_path)
sic5521_ready_to_viz
# Out:
#                    Company Name                  Address             City  \
# 0        R C Foster Truck Sales          1200 W Troy Ave     Indianapolis
# 1        Newark Truck & Tractor        4295 W Us Route 6           Morris
# 2      Munday Truck Sales & Svc     8161 State Road 33 N         Lakeland
# 3        Redline Automotive Inc    5901 Sw 43rd St Ste 4  Fort Lauderdale
# 4                 Truck Country       10930 Limonite Ave        Mira Loma
# ...                         ...                      ...              ...
# 8407  Midwest Truck  Auto Sales       420 S Dirksen Pkwy      Springfield
# 8408             Tnt Enterprise       35547 Grandview Dr          Yucaipa
# 8409  Metropolitan Pit Stop Inc  5324 Laurel Canyon Blvd   Valley Village
# 8410          Stanek Automotive               401 5th St           Malcom
# 8411          Frye Motor Sports   66 Pinnacle Springs Rd       Greenbrier
#
#      State    Zip          County           Phone Contact First Contact Last  \
# ...

# %%
sic5521_ready_to_viz.drop_duplicates(subset=['Company Name', 'Address'], keep='first', inplace=True)
sic5521_ready_to_viz_no_dup = sic5521_ready_to_viz
sic5521_ready_to_viz_no_dup
# Out:
#                         Company Name                Address             City  \
# 0             R C Foster Truck Sales        1200 W Troy Ave     Indianapolis
# 1             Newark Truck & Tractor      4295 W Us Route 6           Morris
# 2           Munday Truck Sales & Svc   8161 State Road 33 N         Lakeland
# 3             Redline Automotive Inc  5901 Sw 43rd St Ste 4  Fort Lauderdale
# 4                      Truck Country     10930 Limonite Ave        Mira Loma
# ...                              ...                    ...              ...
# 7675                Dusty Car Buyerz       5713 Tujunga Ave  North Hollywood
# 7699                 Equipment Ready          7007 Osler St        San Diego
# 7702  Global Truck & Equipment Sales     10193 Live Oak Ave          Fontana
# 7712          Cross Town Enterprises      926 S Superior St           Antigo
# 7726    Peachtre Classic Cars & Auto       355 Lanier Ave E     Fayetteville
#
# ...

# %%
from google.colab import files

sic5521_ready_to_viz_no_dup.to_csv('sic5521_ready_to_viz_no_dup.csv', index=False)

files.download('sic5521_ready_to_viz_no_dup.csv')

# %%
import pandas as pd
from google.colab import sheets

file_path = 'sic5521_ready_to_viz_no_dup.csv'
sic5521_ready_to_viz_no_dup1 = pd.read_csv(file_path)
sic5521_ready_to_viz_no_dup1
# Out:
#                         Company Name                Address             City  \
# 0             R C Foster Truck Sales        1200 W Troy Ave     Indianapolis
# 1             Newark Truck & Tractor      4295 W Us Route 6           Morris
# 2           Munday Truck Sales & Svc   8161 State Road 33 N         Lakeland
# 3             Redline Automotive Inc  5901 Sw 43rd St Ste 4  Fort Lauderdale
# 4                      Truck Country     10930 Limonite Ave        Mira Loma
# ...                              ...                    ...              ...
# 2751                Dusty Car Buyerz       5713 Tujunga Ave  North Hollywood
# 2752                 Equipment Ready          7007 Osler St        San Diego
# 2753  Global Truck & Equipment Sales     10193 Live Oak Ave          Fontana
# 2754          Cross Town Enterprises      926 S Superior St           Antigo
# 2755    Peachtre Classic Cars & Auto       355 Lanier Ave E     Fayetteville
#
# ...

# %%
#the function to show the distribution of a certain column
def col_dist(column):
  return sic5521_ready_to_viz_no_dup1[column].value_counts()

col_dist('SIC Code')
# Out:
# SIC Code
# 552101    689
# 552199    681
# 552102    479
# 552100    443
# 552103    399
# 552198     65
# Name: count, dtype: int64
